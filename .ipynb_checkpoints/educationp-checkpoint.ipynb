# %% [markdown]
# # import libraries

# %%
import pandas as pd  # import libraries
import numpy as np

# %%
import matplotlib.pyplot as plt  # import visual libraries
import seaborn as sns

# %% [markdown]
# ## Read CSV

# %%
data=pd.read_csv(r'C:\Users\Azadeh\Desktop\education data\data.csv', sep=";")
# read csv with "";"" seperator

# %% [markdown]
# # first (head)  and end (tail) 5 rows

# %%
data.head()  # first 5 rows
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
data.tail()    # end 5 rows
# Out:
#       Marital status  Application mode  Application order  Course  \
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 4419                             1                       1
# 4420                             1                       1
# 4421                             1                       1
# 4422                             1                       1
# 4423                             1                       1
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 4419                           125.0            1                       1
# ...

# %%
n = len(pd.unique(data['Target'])) 
n
 # how many unique values in "target" column
# Out:
# 3

# %%
visited = []
for i in range(0, len(data['Target'])):
 
    if data['Target'][i] not in visited:
 
        visited.append(data['Target'][i])
   
 
print("unique values :",
      visited)
 # What are unique values in "target" column
# Out:
# unique values : ['Dropout', 'Graduate', 'Enrolled']

# %%
data=data.replace(to_replace=['Dropout', 'Graduate', 'Enrolled'], value=[1, 2 , 3])
data
# change values to numbers
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 0                                1                       1
# ...

# %% [markdown]
# ## data shape

# %%
data.shape
# Out:
# (4424, 37)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance	                     4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %% [markdown]
#   # Check null value

# %%
data.isnull()  
# checking for null values
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0              False             False              False   False
# 1              False             False              False   False
# 2              False             False              False   False
# 3              False             False              False   False
# 4              False             False              False   False
# ...              ...               ...                ...     ...
# 4419           False             False              False   False
# 4420           False             False              False   False
# 4421           False             False              False   False
# 4422           False             False              False   False
# 4423           False             False              False   False
#
#       Daytime/evening attendance\t  Previous qualification  \
# 0                            False                   False
# ...

# %%
data.isnull().sum()
# number of null values
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance\t                      0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# ...

# %%
data.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance\t  Previous qualification  \
# count                   4424.000000             4424.000000
# mean                       0.890823                4.577758
# std                        0.311897               10.216592
# min                        0.000000                1.000000
# ...

# %% [markdown]
# # correlation

# %%
data.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance\t', 'Previous qualification',
#        'Previous qualification (grade)', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Admission grade',
#        'Displaced', 'Educational special needs', 'Debtor',
#        'Tuition fees up to date', 'Gender', 'Scholarship holder',
#        'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
# ...

# %%
data1=data.drop('Target', axis=1)
# deleting "Target" value

# %%
sns.heatmap(data1)
# Out:
# C:\Users\Azadeh\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Azadeh\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)
# <AxesSubplot:>

# %%
# plotting correlation heatmap 
dataplot = sns.heatmap(data.corr(), cmap="YlGnBu", annot=True)

# %%
x=data1
x.head(1)


# x dataset
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
#
#    Father's qualification  ...  \
# 0                      12  ...
#
#    Curricular units 1st sem (without evaluations)  \
# 0                                               0
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                               0.0
#
# ...

# %%
data['Target'] = data['Target'].astype(int)
y=data['Target']
y.head(5)

# y dataset
# Out:
# 0    1
# 1    2
# 2    1
# 3    2
# 4    2
# Name: Target, dtype: int32

# %% [markdown]
# # Test and Train

# %%
from sklearn.model_selection import train_test_split
# importing train_test_split  from sklearn.model_selection

# %%
x_train,x_test,y_train, y_test=train_test_split(x,y,test_size=0.3, random_state=43)
# train and test size

# %% [markdown]
# # scailing

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x_train=sc.fit_transform(x_train)

# %%
x_test=sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.28940567, -0.98870882,  0.20293792, ..., -1.48521919,
#          0.99695852,  0.14283436],
#        [-0.28940567, -0.98870882,  2.47115379, ...,  0.87181583,
#         -1.10512508,  0.34886245],
#        [-0.28940567, -0.98870882, -0.55313404, ...,  1.4704279 ,
#          1.14192981, -1.77717206],
#        ...,
#        [ 1.40116027,  1.19009154, -0.55313404, ..., -0.99884688,
#          0.12713082,  1.5411952 ],
#        [-0.28940567, -0.01398234,  2.47115379, ...,  0.31061702,
#         -0.52523995,  0.78722008],
#        [-0.28940567, -0.98870882, -0.55313404, ...,  1.73232068,
#         -0.67021123, -0.4007291 ]])

# %%
x_test
# Out:
# array([[-0.28940567,  1.19009154, -0.55313404, ...,  0.87181583,
#         -1.10512508,  0.34886245],
#        [-0.28940567, -0.07131919, -0.55313404, ...,  0.42285678,
#          1.79430058, -0.74264805],
#        [-0.28940567, -0.98870882, -0.55313404, ..., -0.17575529,
#         -0.45275431,  0.88804233],
#        ...,
#        [-0.28940567,  1.87813376, -0.55313404, ..., -0.99884688,
#          0.12713082,  1.5411952 ],
#        [-0.28940567,  1.4767758 , -0.55313404, ...,  0.87181583,
#         -1.10512508,  0.34886245],
#        [-0.28940567, -0.98870882,  0.95900987, ..., -0.81178061,
#         -1.46755329, -1.36511589]])

# %% [markdown]
# # import linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %% [markdown]
# # Model training  Fit Models

# %%
lr=LinearRegression()
lr.fit(x_train, y_train)  # fir models with .fit method

svm1=SVR()
svm1.fit(x_train, y_train)

rf=RandomForestRegressor()
rf.fit(x_train, y_train)

gr=GradientBoostingRegressor()
gr.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_predlr=lr.predict(x_test)
y_predsvm=svm1.predict(x_test)
y_predrf=rf.predict(x_test)
y_predgr=gr.predict(x_test)

# %% [markdown]
# # Evaluating  algorithems

# %%
from sklearn import metrics

# %%
scorelr=metrics.r2_score(y_test,y_predlr)
scoresvm=metrics.r2_score(y_test,y_predsvm)
scorerf=metrics.r2_score(y_test,y_predrf)
scoregr=metrics.r2_score(y_test,y_predgr)

# %%
print (scorelr)
print (scoresvm)
print (scorerf)
print (scoregr)
# Out:
# 0.28696214266357056
# 0.2972470832832841
# 0.34093125338105656
# 0.3389687799978729

# %%
final_data=pd.DataFrame({"models":["LR", "SVR" , "RF" , "GR"] , "R2_Square":[scorelr,scoresvm,scorerf,scoregr]})
# making a data frame with r2 scores and models

# %%
final_data
# Out:
#   models  R2_Square
# 0     LR   0.286962
# 1    SVR   0.297247
# 2     RF   0.340931
# 3     GR   0.338969

# %%
sns.barplot(final_data["models"],final_data["R2_Square"])
# Out:
# C:\Users\Azadeh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='models', ylabel='R2_Square'>

# %% [markdown]
# # Classification models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
# import classifier models

# %%
from sklearn.metrics import accuracy_score
# import evluation accuracy

# %% [markdown]
# # Classification Model training

# %%
lr2=LogisticRegression()
lr2.fit(x_train, y_train)
yPredlr=lr.predict(x_test)
y_train.head(5)
# Out:
# 4365    2
# 2824    3
# 909     1
# 3637    3
# 2409    1
# Name: Target, dtype: int32

# %%
yPredlr_df = pd.DataFrame(yPredlr)  # change numpy arrey to pandas data frame
yPredlr_df.head(5)
# Out:
#           0
# 0  1.833061
# 1  2.008928
# 2  1.989372
# 3  0.886731
# 4  1.896533

# %%
print(yPredlr_df.dtypes)  # check data type
# Out:
# 0    float64
# dtype: object

# %%
yPredlr_df = yPredlr_df.astype(int)  # change data type float to integer

# %%
print(yPredlr_df.dtypes) # checking data type
# Out:
# 0    int32
# dtype: object

# %%
acclr=accuracy_score(y_test, yPredlr_df) # accuracy
print(acclr)
# Out:
# 0.5993975903614458

# %%
lr2=LogisticRegression()
lr2.fit(x_train, y_train)
yPredlr=lr.predict(x_test)
yPredlr_df = pd.DataFrame(yPredlr)
yPredlr_df = yPredlr_df.astype(int)# change numpy arrey to pandas data frame
acclr=accuracy_score(y_test, yPredlr_df) # accuracy
print(acclr)
# Out:
# 0.5993975903614458

# %%
from sklearn.svm import SVC
svm2=svm.SVC()
svm2.fit(x_train, y_train)
yPredsvm=svm2.predict(x_test)
accsvm=accuracy_score(y_test,yPredsvm)
accsvm
# Out:
# 0.7515060240963856

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
yPredknn=knn.predict(x_test)
accknn=accuracy_score(y_test,yPredknn)
accknn
# Out:
# 0.6799698795180723

# %%
rf2=RandomForestClassifier()
rf2.fit(x_train,y_train)
yPredrf2=rf2.predict(x_test)
accrf2=accuracy_score(y_test,yPredrf2)
accrf2
# Out:
# 0.7620481927710844

# %%
gr2=GradientBoostingClassifier()
gr2.fit(x_train , y_train)
yPredgr=gr2.predict(x_test)
accgr2=accuracy_score(y_test,yPredgr)
accgr2
# Out:
# 0.7635542168674698

# %%
#final_data2=pd.DataFrame({"models":["LR", "SVR" , "RF" , "GR"] , "R2_Square":[scorelr,scoresvm,scorerf,scoregr]})
# making a data frame with r2 scores and models

# %%
final_data2=pd.DataFrame({"models":["LR","SVC","KNN","RF","GBC"],"ACCScore":[acclr,accsvm,accknn,accrf2,accgr2]})
# making a data frame with acc score scores and classification models

# %%
final_data2
# Out:
#   models  ACCScore
# 0     LR  0.599398
# 1    SVC  0.751506
# 2    KNN  0.679970
# 3     RF  0.762048
# 4    GBC  0.763554

# %%
sns.barplot(final_data2["models"],final_data2["ACCScore"])
# Out:
# C:\Users\Azadeh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='models', ylabel='ACCScore'>

# %% [markdown]
# # Save the Model

# %%
import joblib

# %%
sc=StandardScaler()
xSc=sc.fit_transform(x)
#xSc
y=np.array(y)
y
# Out:
# array([1, 2, 1, ..., 1, 2, 2])

# %%
GR=GradientBoostingClassifier()

# %%
GR.fit(xSc,y)
# Out:
# GradientBoostingClassifier()

# %%
joblib.dump(gr,"Education Status")
# Out:
# ['Education Status']

# %%
Model=joblib.load("Education Status")

# %%
data.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance\t', 'Previous qualification',
#        'Previous qualification (grade)', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Admission grade',
#        'Displaced', 'Educational special needs', 'Debtor',
#        'Tuition fees up to date', 'Gender', 'Scholarship holder',
#        'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
# ...
